# %% [markdown]
# ## Эксперимент 1
# Проверить, способны ли методы выдавать строгую разреженность векторов.

# %%
import sys
import os
import matplotlib.pyplot as plt
sys.path.append('../src')

# %%
import compare_methods as template

# %%
template.run_experiment_1("regression", "abalone", "3_2")
# Out:
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_abalone_1.png
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_abalone_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [6.67572021484375e-06,
#                 0.0010771751403808594,
#                 0.0018703937530517578,
#                 0.00270843505859375,
#                 0.003566265106201172,
#                 0.0044596195220947266,
#                 0.005234241485595703,
#                 0.006052970886230469,
#                 0.006878376007080078,
#                 0.007641315460205078,
#                 0.008510589599609375,
#                 0.009292125701904297,
#                 0.011270523071289062,
#                 0.013195991516113281,
#                 0.014439821243286133,
#                 0.015298843383789062,
#                 0.016306400299072266,
#                 0.017102718353271484,
#                 0.01793694496154785,
# ...

# %%
template.run_experiment_1("regression", "bodyfat","3_2")
# Out:
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_bodyfat_1.png
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_bodyfat_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [4.2438507080078125e-05,
#                 0.0003592967987060547,
#                 0.0006351470947265625,
#                 0.0009076595306396484,
#                 0.0011761188507080078,
#                 0.001444101333618164,
#                 0.0017135143280029297,
#                 0.0020384788513183594,
#                 0.0023245811462402344,
#                 0.0025954246520996094,
#                 0.0029807090759277344,
#                 0.0032651424407958984,
#                 0.0035326480865478516,
#                 0.0038030147552490234,
#                 0.004133939743041992,
#                 0.004479169845581055,
#                 0.004936933517456055,
#                 0.0052433013916015625,
# ...

# %%
template.run_experiment_1("binary","a9a","3_2")
# Out:
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_a9a_1.png
# График сохранён: /home/zver/itmo/met-opts/metopts/opt_project_lab_3/plots/3_2_a9a_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [9.059906005859375e-06,
#                 0.004307985305786133,
#                 0.008546829223632812,
#                 0.015066862106323242,
#                 0.02117323875427246,
#                 0.027994871139526367,
#                 0.03428363800048828,
#                 0.040418148040771484,
#                 0.04761004447937012,
#                 0.05415058135986328,
#                 0.061501264572143555,
#                 0.06708860397338867,
#                 0.07274222373962402,
#                 0.07855939865112305,
#                 0.08441019058227539,
#                 0.09250688552856445,
#                 0.10128903388977051,
#                 0.10718441009521484,
#                 0.11547541618347168,
# ...
