# %%
import sys
import os
import matplotlib.pyplot as plt
sys.path.append('../src')

# %%
import compare_methods as template

# %%
template.run_experiment_2("regression","abalone",0.03, "3_3")
# Out:
# F* = 1.858367, R = 17.6347
# Запуск Subgradient...
# Запуск ISTA...
# Запуск FISTA...
# Запуск Frank-Wolfe...
# Запуск Barrier...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_abalone_0.03_1.png
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_abalone_0.03_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [2.1457672119140625e-06,
#                 0.00024271011352539062,
#                 0.000453948974609375,
#                 0.0006563663482666016,
#                 0.0008661746978759766,
#                 0.001070261001586914,
#                 0.0012657642364501953,
#                 0.0014600753784179688,
#                 0.0016541481018066406,
#                 0.001847982406616211,
#                 0.0020449161529541016,
#                 0.002237558364868164,
#                 0.0024313926696777344,
#                 0.0026242733001708984,
#                 0.002815723419189453,
# ...

# %%
template.run_experiment_2("regression", "bodyfat",0.005,"3_3")
# Out:
# F* = 0.018801, R = 1.9463
# Запуск Subgradient...
# Запуск ISTA...
# Запуск FISTA...
# Запуск Frank-Wolfe...
# Запуск Barrier...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_bodyfat_0.005_1.png
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_bodyfat_0.005_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [1.430511474609375e-06,
#                 0.0003383159637451172,
#                 0.00045180320739746094,
#                 0.0005207061767578125,
#                 0.0005803108215332031,
#                 0.0006363391876220703,
#                 0.0006930828094482422,
#                 0.0007481575012207031,
#                 0.0008111000061035156,
#                 0.0008699893951416016,
#                 0.000926971435546875,
#                 0.0009832382202148438,
#                 0.0010409355163574219,
#                 0.0011010169982910156,
#                 0.00115966796875,
# ...

# %%
template.run_experiment_2("binary","a9a",0.0009,"3_3")
# Out:
# F* = 0.559959, R = 12.6583
# Запуск Subgradient...
# Запуск ISTA...
# Запуск FISTA...
# Запуск Frank-Wolfe...
# Запуск Barrier...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_a9a_0.0009_1.png
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_a9a_0.0009_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [2.1457672119140625e-06,
#                 0.0013995170593261719,
#                 0.0027348995208740234,
#                 0.004254341125488281,
#                 0.005918979644775391,
#                 0.0075490474700927734,
#                 0.009225130081176758,
#                 0.010924339294433594,
#                 0.012600183486938477,
#                 0.014286279678344727,
#                 0.01590585708618164,
#                 0.017549991607666016,
#                 0.019153118133544922,
#                 0.020795345306396484,
#                 0.022417545318603516,
# ...

# %%
template.run_experiment_2("binary","a9a", 0.001 ,"3_3")
# Out:
# F* = 0.561215, R = 12.4443
# Запуск Subgradient...
# Запуск ISTA...
# Запуск FISTA...
# Запуск Frank-Wolfe...
# Запуск Barrier...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_a9a_0.001_1.png
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_3_a9a_0.001_2.png
# ({'Subgradient': defaultdict(list,
#               {'time': [1.430511474609375e-06,
#                 0.0011415481567382812,
#                 0.002228260040283203,
#                 0.0034568309783935547,
#                 0.004790782928466797,
#                 0.006108760833740234,
#                 0.007501363754272461,
#                 0.008898735046386719,
#                 0.010285377502441406,
#                 0.011678218841552734,
#                 0.013055562973022461,
#                 0.014427900314331055,
#                 0.015787839889526367,
#                 0.01714181900024414,
#                 0.018499374389648438,
# ...
