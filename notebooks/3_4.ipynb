# %%
import sys
import os
import matplotlib.pyplot as plt
sys.path.append('../src')

# %%
import compare_methods as template

# %%
template.run_experiment_3("regression","abalone",0.03)
# Out:
# Датасет: abalone, m=4177, n=8
# F* = 1.858367, R = 17.6347
# 3.1 ISTA vs FISTA...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_abalone_0.03_1.png
# 3.2 Frank-Wolfe: standard vs armijo...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_abalone_0.03_2.png
# 3.3 Barrier: mu = [2, 5, 10, 20, 30, 40, 50, 100]
#   mu=2...
#   mu=5...
#   mu=10...
#   mu=20...
#   mu=30...
#   mu=40...
#   mu=50...
#   mu=100...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_abalone_0.03_3.png

# %%
template.run_experiment_3("regression", "bodyfat",0.005)
# Out:
# Датасет: bodyfat, m=252, n=14
# F* = 0.018801, R = 1.9463
# 3.1 ISTA vs FISTA...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_bodyfat_0.005_1.png
# 3.2 Frank-Wolfe: standard vs armijo...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_bodyfat_0.005_2.png
# 3.3 Barrier: mu = [2, 5, 10, 20, 30, 40, 50, 100]
#   mu=2...
#   mu=5...
#   mu=10...
#   mu=20...
#   mu=30...
#   mu=40...
#   mu=50...
#   mu=100...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_bodyfat_0.005_3.png

# %%
template.run_experiment_3("binary","a9a",0.0009)
# Out:
# Датасет: a9a, m=32561, n=123
# F* = 0.559959, R = 12.6583
# 3.1 ISTA vs FISTA...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.0009_1.png
# 3.2 Frank-Wolfe: standard vs armijo...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.0009_2.png
# 3.3 Barrier: mu = [2, 5, 10, 20, 30, 40, 50, 100]
#   mu=2...
#   mu=5...
#   mu=10...
#   mu=20...
#   mu=30...
#   mu=40...
#   mu=50...
#   mu=100...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.0009_3.png

# %%
template.run_experiment_3("binary","a9a", 0.001 )
# Out:
# Датасет: a9a, m=32561, n=123
# F* = 0.561215, R = 12.4443
# 3.1 ISTA vs FISTA...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.001_1.png
# 3.2 Frank-Wolfe: standard vs armijo...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.001_2.png
# 3.3 Barrier: mu = [2, 5, 10, 20, 30, 40, 50, 100]
#   mu=2...
#   mu=5...
#   mu=10...
#   mu=20...
#   mu=30...
#   mu=40...
#   mu=50...
#   mu=100...
# График сохранён: /home/vchepelin/Repositories/opt_project_lab_3/plots/3_4_a9a_0.001_3.png
